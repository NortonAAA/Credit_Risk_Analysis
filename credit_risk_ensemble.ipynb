# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# https://help.lendingclub.com/hc/en-us/articles/215488038-What-do-the-different-Note-statuses-mean-

columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
# Load the data
file_path = Path('LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# Remove the `Issued` loan status
issued_mask = df['loan_status'] != 'Issued'
df = df.loc[issued_mask]

# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100


# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["issue_d"]=le.fit_transform(df["issue_d"])
df["next_pymnt_d"] = le.fit_transform(df["next_pymnt_d"])
df["initial_list_status"] = le.fit_transform(df["initial_list_status"])
df["application_type"] = le.fit_transform(df["application_type"])
df["verification_status"] = le.fit_transform(df["verification_status"])
df.head(20)
# Out:
#     loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     10500.0    0.1719       375.35           RENT     66000.0
# 1     25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2     20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3     10000.0    0.1640       353.55           RENT     92000.0
# 4     22000.0    0.1474       520.39       MORTGAGE     52000.0
# 5     25000.0    0.1797       634.43       MORTGAGE     90000.0
# 6     20400.0    0.2000       540.48           RENT     51315.0
# 7     10000.0    0.1557       349.46            OWN     66000.0
# 8     14000.0    0.0881       443.96           RENT     45000.0
# 9     10000.0    0.1474       345.39           RENT     63295.0
# 10     8500.0    0.0819       267.11           RENT     75000.0
# 11    10000.0    0.1171       330.76           RENT     54000.0
# 12    30000.0    0.1033       642.30       MORTGAGE    100000.0
# 13    15800.0    0.1640       387.60       MORTGAGE     62000.0
# 14    18000.0    0.1557       433.63       MORTGAGE     60000.0
# 15    40000.0    0.2250      1537.99       MORTGAGE     54000.0
# 16    14400.0    0.1390       491.46           RENT    100350.0
# 17     9600.0    0.0881       304.43           RENT     92000.0
# 18    16000.0    0.1719       399.28       MORTGAGE     72500.0
# 19    20000.0    0.0756       622.68           RENT    175000.0
#
#     verification_status  issue_d loan_status pymnt_plan    dti  ...  \
# 0                     1        2    low_risk          n  27.24  ...
# 1                     2        2    low_risk          n  20.23  ...
# 2                     2        2    low_risk          n  24.26  ...
# 3                     2        2    low_risk          n  31.44  ...
# 4                     0        2    low_risk          n  18.76  ...
# 5                     1        2    low_risk          n  18.49  ...
# 6                     1        2    low_risk          n  25.63  ...
# 7                     1        2    low_risk          n   9.00  ...
# 8                     0        2    low_risk          n  10.24  ...
# 9                     2        2    low_risk          n  39.34  ...
# 10                    0        2    low_risk          n  17.31  ...
# 11                    0        2    low_risk          n  21.49  ...
# 12                    1        2    low_risk          n   8.00  ...
# 13                    1        2    low_risk          n   8.44  ...
# 14                    2        2    low_risk          n  62.80  ...
# 15                    2        2    low_risk          n  59.09  ...
# 16                    1        2    low_risk          n  30.42  ...
# 17                    0        2    low_risk          n  20.01  ...
# 18                    1        2    low_risk          n  17.00  ...
# 19                    0        2    low_risk          n  11.28  ...
#
#     pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0             85.7             100.0                   0.0        0.0
# 1             91.2              50.0                   1.0        0.0
# 2             66.7              50.0                   0.0        0.0
# 3            100.0              50.0                   1.0        0.0
# 4            100.0               0.0                   0.0        0.0
# 5             93.1              66.7                   0.0        0.0
# 6            100.0               0.0                   1.0        0.0
# 7            100.0              16.7                   0.0        0.0
# 8            100.0               0.0                   0.0        0.0
# 9             97.2              71.4                   0.0        0.0
# 10           100.0               0.0                   0.0        0.0
# 11           100.0               0.0                   0.0        0.0
# 12           100.0               0.0                   0.0        0.0
# 13           100.0              50.0                   0.0        0.0
# 14           100.0              25.0                   0.0        0.0
# 15           100.0             100.0                   0.0        0.0
# 16            98.1               7.7                   1.0        0.0
# 17            76.2             100.0                   0.0        0.0
# 18           100.0              50.0                   0.0        0.0
# 19            93.8              75.0                   0.0        0.0
#
#     tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0           65687.0            38199.0          2000.0
# 1          271427.0            60641.0         41200.0
# 2           60644.0            45684.0          7500.0
# 3           99506.0            68784.0         19700.0
# 4          219750.0            25919.0         27600.0
# 5          550717.0           418934.0         18800.0
# 6           40023.0            23469.0          3500.0
# 7           29300.0            22377.0          8400.0
# 8           25100.0             9724.0         12100.0
# 9          119822.0           102924.0         15300.0
# 10          75000.0            57756.0         18000.0
# 11         152500.0            42343.0         85000.0
# 12          50200.0            17323.0         29200.0
# 13         195700.0            18726.0         15900.0
# 14         196496.0           170509.0         10200.0
# 15         123858.0           107194.0         19100.0
# 16         156028.0           104873.0         49000.0
# 17          58335.0            43218.0          6300.0
# 18         217738.0            52114.0          8500.0
# 19          84966.0            65106.0         20500.0
#
#     total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                      61987.0              N                     N
# 1                      49197.0              N                     N
# 2                      43144.0              N                     N
# 3                      76506.0              N                     N
# 4                      20000.0              N                     N
# 5                     369051.0              N                     N
# 6                      27523.0              N                     N
# 7                      12500.0              N                     N
# 8                       3000.0              N                     N
# 9                      80722.0              N                     N
# 10                     57000.0              N                     N
# 11                     65500.0              N                     N
# 12                     20000.0              N                     N
# 13                      4100.0              N                     N
# 14                     73796.0              N                     N
# 15                     64858.0              N                     N
# 16                     88928.0              N                     N
# 17                     46535.0              N                     N
# 18                     49727.0              N                     N
# 19                     55785.0              N                     N
#
# [20 rows x 86 columns]

# %%
# Create our features
X = df.drop(columns="loan_status")
X = pd.get_dummies(X)

# Create our target
y = df.loc[:, target].copy()

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04
# mean   16677.594562      0.127718    480.652863  8.821371e+04
# std    10277.348590      0.048130    288.062432  1.155800e+05
# min     1000.000000      0.060000     30.890000  4.000000e+01
# 25%     9000.000000      0.088100    265.730000  5.000000e+04
# 50%    15000.000000      0.118000    404.560000  7.300000e+04
# 75%    24000.000000      0.155700    648.100000  1.040000e+05
# max    40000.000000      0.308400   1676.230000  8.797500e+06
#
#        verification_status       issue_d           dti   delinq_2yrs  \
# count         68817.000000  68817.000000  68817.000000  68817.000000
# mean              0.669994      0.805542     21.778153      0.217766
# std               0.719105      0.714932     20.199244      0.718367
# min               0.000000      0.000000      0.000000      0.000000
# 25%               0.000000      0.000000     13.890000      0.000000
# 50%               1.000000      1.000000     19.760000      0.000000
# 75%               1.000000      1.000000     26.660000      0.000000
# max               2.000000      2.000000    999.000000     18.000000
#
#        inq_last_6mths      open_acc  ...  total_bal_ex_mort  total_bc_limit  \
# count    68817.000000  68817.000000  ...       6.881700e+04    68817.000000
# mean         0.497697     12.587340  ...       6.133843e+04    29734.128558
# std          0.758122      6.022869  ...       5.738798e+04    26795.394232
# min          0.000000      2.000000  ...       2.350000e+02      100.000000
# 25%          0.000000      8.000000  ...       2.650300e+04    11600.000000
# 50%          0.000000     11.000000  ...       4.535700e+04    22100.000000
# 75%          1.000000     16.000000  ...       7.657000e+04    39300.000000
# max          5.000000     72.000000  ...       1.295455e+06   509400.000000
#
#        total_il_high_credit_limit  home_ownership_ANY  \
# count                6.881700e+04        68817.000000
# mean                 5.572240e+04            0.009285
# std                  5.095845e+04            0.095914
# min                  1.270000e+02            0.000000
# 25%                  2.288000e+04            0.000000
# 50%                  4.200000e+04            0.000000
# 75%                  7.249900e+04            0.000000
# max                  1.426964e+06            1.000000
#
#        home_ownership_MORTGAGE  home_ownership_OWN  home_ownership_RENT  \
# count             68817.000000        68817.000000         68817.000000
# mean                  0.526309            0.106747             0.357659
# std                   0.499311            0.308793             0.479314
# min                   0.000000            0.000000             0.000000
# 25%                   0.000000            0.000000             0.000000
# 50%                   1.000000            0.000000             0.000000
# 75%                   1.000000            0.000000             1.000000
# max                   1.000000            1.000000             1.000000
#
#        pymnt_plan_n  hardship_flag_N  debt_settlement_flag_N
# count       68817.0          68817.0                 68817.0
# mean            1.0              1.0                     1.0
# std             0.0              0.0                     0.0
# min             1.0              1.0                     1.0
# 25%             1.0              1.0                     1.0
# 50%             1.0              1.0                     1.0
# 75%             1.0              1.0                     1.0
# max             1.0              1.0                     1.0
#
# [8 rows x 88 columns]

# %%
# Check the balance of our target values
y['loan_status'].value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1,stratify=y)
# Create the scaler instance
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
#Fitting the scaler
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Ensemble Learners
#
# In this section, you will compare two ensemble algorithms to determine which algorithm results in the best performance. You will train a Balanced Random Forest Classifier and an Easy Ensemble AdaBoost classifier . For each algorithm, be sure to complete the folliowing steps:
#
# 1. Train the model using the training data.
# 2. Calculate the balanced accuracy score from sklearn.metrics.
# 3. Print the confusion matrix from sklearn.metrics.
# 4. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
# 5. For the Balanced Random Forest Classifier onely, print the feature importance sorted in descending order (most important feature to least important) along with the feature score
#
# Note: Use a random state of 1 for each algorithm to ensure consistency between tests

# %% [markdown]
# ### Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

brfc_model = BalancedRandomForestClassifier(n_estimators=100,random_state=1).fit(X_train_scaled,y_train)
brfc_model
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = brfc_model.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.7576668640793518

# %%
# Display the confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[   56,    31],
#        [ 2197, 14921]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.02      0.64      0.87      0.05      0.75      0.55        87
#    low_risk       1.00      0.87      0.64      0.93      0.75      0.57     17118
#
# avg / total       0.99      0.87      0.64      0.93      0.75      0.57     17205

# %%
# List the features sorted in descending order by feature importance
from matplotlib import pyplot as plt

features = brfc_model.feature_importances_
features = sorted(zip(X.columns, brfc_model.feature_importances_), key = lambda x: x[1], reverse=True)
features
# Out:
# [('total_rec_prncp', 0.07266879477243213),
#  ('total_pymnt', 0.06780470344385656),
#  ('last_pymnt_amnt', 0.06340425099150393),
#  ('total_rec_int', 0.06099736341289877),
#  ('total_pymnt_inv', 0.04940949021361182),
#  ('int_rate', 0.02716827148536103),
#  ('issue_d', 0.022994407334388033),
#  ('installment', 0.019073468001169654),
#  ('annual_inc', 0.01826569395962879),
#  ('mths_since_recent_inq', 0.01804982763008323),
#  ('max_bal_bc', 0.017599325357049365),
#  ('out_prncp', 0.01726429992757394),
#  ('out_prncp_inv', 0.017232676938412846),
#  ('all_util', 0.016649535111145506),
#  ('avg_cur_bal', 0.01630351439053317),
#  ('tot_hi_cred_lim', 0.015969820714074184),
#  ('revol_bal', 0.01590389887160123),
#  ('bc_util', 0.01574717911320728),
#  ('dti', 0.015270309398361239),
#  ('tot_cur_bal', 0.014703421118730917),
#  ('mths_since_rcnt_il', 0.01429570343557775),
#  ('total_rev_hi_lim', 0.013741403827879854),
#  ('il_util', 0.013693988856557333),
#  ('bc_open_to_buy', 0.013513623518731836),
#  ('total_bal_il', 0.013426180528617455),
#  ('mths_since_recent_bc', 0.012934540036909081),
#  ('mo_sin_old_rev_tl_op', 0.012912851814900499),
#  ('total_acc', 0.01265002449305798),
#  ('total_bal_ex_mort', 0.012424899044402688),
#  ('mo_sin_old_il_acct', 0.012400102541168374),
#  ('num_sats', 0.011362744611141805),
#  ('total_bc_limit', 0.011330338255434802),
#  ('num_rev_tl_bal_gt_0', 0.011220551794001261),
#  ('loan_amnt', 0.010945301210099624),
#  ('mo_sin_rcnt_rev_tl_op', 0.010800810349289503),
#  ('total_il_high_credit_limit', 0.010717005860408772),
#  ('num_rev_accts', 0.010314010504869749),
#  ('num_actv_bc_tl', 0.009598150546545944),
#  ('open_acc', 0.00912003575399669),
#  ('inq_last_12m', 0.008998938703263319),
#  ('total_rec_late_fee', 0.008786822651926957),
#  ('open_il_24m', 0.008766413230189252),
#  ('mo_sin_rcnt_tl', 0.008547448105038971),
#  ('num_bc_tl', 0.00852467203914977),
#  ('num_actv_rev_tl', 0.008218013907067077),
#  ('inq_fi', 0.008104477954077954),
#  ('num_op_rev_tl', 0.00804517820551267),
#  ('num_bc_sats', 0.00791829566422955),
#  ('total_cu_tl', 0.00783970246043367),
#  ('pct_tl_nvr_dlq', 0.007755141902097485),
#  ('num_il_tl', 0.007445497834659326),
#  ('acc_open_past_24mths', 0.007033550740381855),
#  ('open_act_il', 0.0066668791178276406),
#  ('percent_bc_gt_75', 0.00666649501883791),
#  ('open_rv_24m', 0.006196316880680052),
#  ('num_tl_op_past_12m', 0.006138303447270486),
#  ('open_acc_6m', 0.005867780356019968),
#  ('inq_last_6mths', 0.005833651349939886),
#  ('mort_acc', 0.005604500881799178),
#  ('next_pymnt_d', 0.0051201009674669016),
#  ('open_il_12m', 0.004146503209875033),
#  ('delinq_2yrs', 0.004085958713083811),
#  ('open_rv_12m', 0.004076100621339611),
#  ('num_accts_ever_120_pd', 0.003816497018086718),
#  ('verification_status', 0.0037483914686014166),
#  ('home_ownership_RENT', 0.002355900627484747),
#  ('tot_coll_amt', 0.002165403076829672),
#  ('home_ownership_MORTGAGE', 0.001984055423910219),
#  ('pub_rec_bankruptcies', 0.0018772095149252846),
#  ('home_ownership_OWN', 0.0018629522894351375),
#  ('initial_list_status', 0.0015428266999909551),
#  ('pub_rec', 0.0015235502013656941),
#  ('application_type', 0.001218783143637482),
#  ('num_tl_90g_dpd_24m', 0.0010223755949922999),
#  ('home_ownership_ANY', 0.0002867634393439396),
#  ('chargeoff_within_12_mths', 0.00019579422500460303),
#  ('collections_12_mths_ex_med', 0.00013023414500884064),
#  ('recoveries', 0.0),
#  ('collection_recovery_fee', 0.0),
#  ('policy_code', 0.0),
#  ('acc_now_delinq', 0.0),
#  ('delinq_amnt', 0.0),
#  ('num_tl_120dpd_2m', 0.0),
#  ('num_tl_30dpd', 0.0),
#  ('tax_liens', 0.0),
#  ('pymnt_plan_n', 0.0),
#  ('hardship_flag_N', 0.0),
#  ('debt_settlement_flag_N', 0.0)]

# %% [markdown]
# ### Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1).fit(X_train_scaled,y_train)

# %%
# Calculated the balanced accuracy score
y_pred = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9250768499381574

# %%
# Display the confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[   79,     8],
#        [  991, 16127]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test,y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.07      0.91      0.94      0.14      0.92      0.85        87
#    low_risk       1.00      0.94      0.91      0.97      0.92      0.86     17118
#
# avg / total       0.99      0.94      0.91      0.97      0.92      0.86     17205
